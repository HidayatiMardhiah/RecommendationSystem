# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sea

# %%
# Read the csv file
df = pd.read_csv('../data/youtube_watch_log.csv')

df.head()
# Out:
#    log_id  user_id     video_id           watch_date subscribed playlist_name
# 0     286        1  LT0fuY75i4I  2018-09-13 03:10:18          N           NaN
# 1     289        1  tAdEUOLxuVY  2018-09-13 01:02:39          N           NaN
# 2     292        1  chLIG0nuWCU  2018-09-12 23:52:51          N           NaN
# 3     295        1  WKe3-SUXPug  2018-09-12 22:22:28          N           NaN
# 4     298        1  YAD5bcIvYho  2018-09-12 21:33:27          N           NaN

# %%
# See value of data
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")

# check data types and see missing values
df.info()
# Out:
# Total rows: 1844919
# Total columns: 6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844919 entries, 0 to 1844918
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   log_id         int64
#  1   user_id        int64
#  2   video_id       object
#  3   watch_date     object
#  4   subscribed     object
#  5   playlist_name  object
# dtypes: int64(2), object(4)
# memory usage: 84.5+ MB

# %%
df.isnull().sum()
# Out:
# log_id                 0
# user_id                0
# video_id               0
# watch_date             0
# subscribed        829716
# playlist_name    1794262
# dtype: int64

# %%
# Check sparsity of data to handle imbalanced and sparse interactions.
df['subscribed'].value_counts()
# Out:
# subscribed
# N    824230
# Y    190973
# Name: count, dtype: int64

# %% [markdown]
# # With the values above given, the model will biasly go and predict most interactions are not subscribed. Data is highly imbalance.
#
# # Hence, the imbalanced data needs to be addressed.

# %% [markdown]
# From the data analysed, we can use and choose an approach based on the data laid out.
# Content-Based Filtering: Content-based filtering recommends items similar to those a user liked earlier by analyzing item features and user preference profiles.
# Collaborative Filtering: Collaborative filtering identifies similarities in user behavior and recommends items based on patterns derived from many users.
# Hybrid Recommendation Systems: Hybrid systems combine collaborative and content-based methods to offer more accurate and robust recommendations.
# Knowledge-Based Recommendation Systems: Knowledge-based systems use explicit domain knowledge and user requirements rather than historical behavior to suggest items.
# Context-Aware Recommendation Systems: These systems use contextual information such as time, location, device or mood to personalize recommendations.

# %%
plt.figure(figsize=(8,6))
df['subscribed'].value_counts().plot(kind='bar')
plt.title('Subscription Distribution')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Since there are 1.1 million vidoes watched, it is hard to work with this dataset since it is very sparse where the users are small and the amount of products interacted are a lot
#
# # Possible approaches to handle this -> Filter out the data, select appropriate algorithms and use specialized libraries to optimize data
# # Then I need to store this data.
#
# # Why do i chose this approach????? Even if i want to filter it out, how should i filter it and why i did that?
